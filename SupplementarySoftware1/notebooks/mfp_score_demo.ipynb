# %% [markdown]
# # MFP-Score demo notebook
#
# This notebook documents the Paper2 v7 synthetic-curated MFP-Score/OPR prototype. Run it from the `SupplementarySoftware1/` directory.

# %%
import subprocess, sys, json, csv
from pathlib import Path
subprocess.run([sys.executable, "scripts/candidate_ranking.py"], check=True)

# %%
import csv, json
from pathlib import Path
with open("outputs/mfp_scores.csv", newline="") as f:
    scores = list(csv.DictReader(f))
scores[:5]

# %%
with open("outputs/calibration_summary.json") as f:
    calibration = json.load(f)
calibration

# %% [markdown]
# ## Interpretation boundary
#
# The outputs are demonstration artifacts. They should be used to check the manuscript interface, not as validated predictive performance or experimental evidence.
